# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

# %%
measurements = pd.read_csv('../../../nrao_measurements.csv')
measurements.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target
# 0      90.62       1
# 1      90.93       1
# 2      91.92       1
# 3      93.12       1
# ...

# %%
proj1 = measurements[measurements['project_code'] == '2019.1.00193.S']
proj1
# Out:
#           project_code                                      project_title  \
# 155116  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155117  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155118  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155119  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155120  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155121  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155122  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155123  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155124  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155125  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155126  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155127  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# ...

# %%
proj1['freq_diff'] = proj1['high_freq'] - proj1['low_freq']
# Out:
# /var/folders/vx/9pb2fpkj3m5bkbwxzyx6sz5m0000gn/T/ipykernel_84387/4288373201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proj1['freq_diff'] = proj1['high_freq'] - proj1['low_freq']

# %%
proj1.low_freq.value_counts()
# Out:
# low_freq
# 290.22    2
# 290.24    2
# 290.28    2
# 290.35    2
# 291.21    2
# 291.35    2
# 291.36    2
# 291.92    2
# 301.23    2
# 303.90    2
# 304.05    2
# Name: count, dtype: int64

# %%
proj1.high_freq.value_counts()
# Out:
# high_freq
# 291.41    4
# 290.28    2
# 290.29    2
# 290.34    2
# 290.41    2
# 291.27    2
# 291.98    2
# 301.35    2
# 303.96    2
# 304.11    2
# Name: count, dtype: int64

# %%
sns.histplot(measurements.low_freq)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='low_freq', ylabel='Count'>

# %%
sns.histplot(measurements.high_freq)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='high_freq', ylabel='Count'>

# %%
measurements['freq_diff'] = measurements['high_freq'] - measurements['low_freq']
measurements.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target  freq_diff
# 0      90.62       1       0.24
# 1      90.93       1       0.23
# ...

# %%
sns.histplot(measurements.freq_diff)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='freq_diff', ylabel='Count'>

# %%
sns.boxplot(measurements.freq_diff)
# Out:
# <Axes: >

# %%
smalls = measurements[measurements.freq_diff < 4]

# %%
sns.boxplot(smalls.freq_diff)
# Out:
# <Axes: >

# %%
proj1['freq_med'] = (proj1['low_freq']+ (proj1['freq_diff']/2))
proj1
# Out:
# /var/folders/vx/9pb2fpkj3m5bkbwxzyx6sz5m0000gn/T/ipykernel_84387/474896192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   proj1['freq_med'] = (proj1['low_freq']+ (proj1['freq_diff']/2))
#           project_code                                      project_title  \
# 155116  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155117  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155118  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155119  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155120  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# 155121  2019.1.00193.S  Astrochemical confirmation of a circumplanetar...
# ...

# %%
sns.scatterplot()

# %%
smalls.project_code.value_counts().describe()
# Out:
# count     4528.000000
# mean        67.830610
# std        490.618865
# min          1.000000
# 25%          7.000000
# 50%         12.000000
# 75%         36.000000
# max      24164.000000
# Name: count, dtype: float64

# %%
smalls.groupby(['project_code']).agg({
    'freq_med':'count'
}).sort_values('freq_med', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 smalls.groupby(['project_code']).agg({
#       2     'freq_med':'count'
#       3 }).sort_values('freq_med', ascending=False).head(10)
#
# File ~/miniconda3/envs/nraotest/lib/python3.11/site-packages/pandas/core/groupby/generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File ~/miniconda3/envs/nraotest/lib/python3.11/site-packages/pandas/core/apply.py:175, in Apply.agg(self)
#     172     return self.apply_str()
#     174 if is_dict_like(func):
# ...

# %%
smalls.loc[smalls['project_code'] == '2017.1.00886.L'].project_abstract
# Out:
# 96492    For 30 years, our observational understanding ...
# 96216    For 30 years, our observational understanding ...
# 96304    For 30 years, our observational understanding ...
# 96316    For 30 years, our observational understanding ...
# 96516    For 30 years, our observational understanding ...
#                                ...
# 96199    For 30 years, our observational understanding ...
# 96327    For 30 years, our observational understanding ...
# 96147    For 30 years, our observational understanding ...
# 96435    For 30 years, our observational understanding ...
# 96371    For 30 years, our observational understanding ...
# Name: project_abstract, Length: 332, dtype: object

# %%
proj1['freq_med'].describe()
# Out:
# count     22.000000
# mean     294.223636
# std        5.632061
# min      290.250000
# 25%      290.327500
# 50%      291.380000
# 75%      298.955000
# max      304.080000
# Name: freq_med, dtype: float64

# %%
smalls = smalls.drop_duplicates()
smalls.shape, measurements.shape
# Out:
# ((67433, 8), (307139, 8))

# %%
smalls = smalls.sort_values(['project_code', 'low_freq'], ascending=True)
smalls.head()
# Out:
#       project_code                                      project_title  \
# 12  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 8   2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 13  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 9   2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 10  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                      project_abstract fs_type  low_freq  \
# 12  Centaurus A with its host NGC5128 is the most ...    line     85.96
# 8   Centaurus A with its host NGC5128 is the most ...    line     87.05
# 13  Centaurus A with its host NGC5128 is the most ...    line     87.47
# 9   Centaurus A with its host NGC5128 is the most ...    line     87.65
# 10  Centaurus A with its host NGC5128 is the most ...    line     88.36
#
#     high_freq  target  freq_diff
# 12      86.19       1       0.23
# 8       87.29       1       0.24
# ...

# %%
smalls['freq_med'] = (smalls['low_freq']+ (smalls['freq_diff']/2))
# Out:
# /var/folders/vx/9pb2fpkj3m5bkbwxzyx6sz5m0000gn/T/ipykernel_84387/2406211997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smalls['freq_med'] = (smalls['low_freq']+ (smalls['freq_diff']/2))

# %%
smalls.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target  freq_diff  freq_med
# 0      90.62       1       0.24    90.500
# ...

# %%
lines = smalls.query('fs_type == "line"')

# %%
lines.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target  freq_diff  freq_med
# 0      90.62       1       0.24    90.500
# ...

# %%
sns.histplot(lines.freq_med)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='freq_med', ylabel='Count'>

# %% [markdown]
# ## Add 3-d plot with median on X, difference on y, color for count
# ## Add 3-d plot with median, difference, and number of projects

# %%
sns.histplot(lines.freq_diff)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='freq_diff', ylabel='Count'>

# %%
lines['log_diff'] = np.log(lines.freq_diff)
# Out:
# /var/folders/vx/9pb2fpkj3m5bkbwxzyx6sz5m0000gn/T/ipykernel_84387/1619053167.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lines['log_diff'] = np.log(lines.freq_diff)

# %%
lines.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target  freq_diff  freq_med  log_diff
# 0      90.62       1       0.24    90.500 -1.427116
# ...

# %%
sns.relplot(data=lines, x='log_diff', y='freq_med', alpha=0.2)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.relplot(data=lines, x='freq_diff', y='freq_med', alpha=0.2)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.relplot(data=smalls, x='low_freq', y='high_freq')
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
stacked = smalls.query('fs_type == "line"').groupby('project_code').agg({
    'low_freq':'min',
    'high_freq':'max'
})
stacked.head()
# Out:
#                 low_freq  high_freq
# project_code
# 2011.0.00010.S     85.96     220.46
# 2011.0.00017.S     84.09     110.72
# 2011.0.00020.S    251.53     357.87
# 2011.0.00028.S    342.36     357.66
# 2011.0.00039.S    338.32     354.08

# %%
sns.relplot(data=stacked, x='low_freq', y='high_freq', alpha=0.2)
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
stacked.sample(10)
# Out:
#                 low_freq  high_freq
# project_code
# 2017.1.00681.S    219.34     230.42
# 2019.1.00008.S    251.16     254.80
# 2023.1.01128.S    330.27     346.14
# 2018.1.00045.S    230.06     231.00
# 2013.1.01223.S     92.95     109.17
# 2018.1.01194.S    217.04     233.53
# 2015.1.01286.S     85.75     357.49
# 2016.1.01265.S    100.46     305.13
# 2013.1.01391.S     86.31      93.21
# 2016.1.01504.S    343.85     359.48

# %%
stacked['total_dist'] = stacked.high_freq - stacked.low_freq
stacked['total_med'] = stacked.total_dist/2

# %%
stacked.describe()
# Out:
#           low_freq    high_freq   total_dist    total_med
# count  3628.000000  3628.000000  3628.000000  3628.000000
# mean    211.204644   260.188018    48.983374    24.491687
# std     114.474320   129.201309    85.289926    42.644963
# min      35.140000    44.040000     0.060000     0.030000
# 25%     100.070000   157.340000    12.620000     6.310000
# 50%     216.860000   235.930000    15.920000     7.960000
# 75%     251.220000   345.912500    30.800000    15.400000
# max     884.470000   907.940000   621.770000   310.885000

# %%
sns.relplot(data=stacked, x='low_freq', y='high_freq')
# Out:
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ryanlipps/miniconda3/envs/nraotest/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
