# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import plotly_express as px
import textparser   # For potential use later
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from textparser import TextParser
from ast import literal_eval
from sklearn.naive_bayes import MultinomialNB
import sklearn

# %%
measurements = pd.read_csv('nrao_measurements.csv')
measurements = measurements.drop_duplicates()
measurements['freq_diff'] = measurements['high_freq'] - measurements['low_freq']
measurements = measurements[measurements.freq_diff < 5] #Adele mentioned that frequency range should never be greater than 4
measurements['freq_med'] = (measurements['low_freq']+ (measurements['freq_diff']/2))
measurements = measurements.query('fs_type == "line"')
measurements.head()
# Out:
#      project_code                                      project_title  \
# 0  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 1  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 2  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 3  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
# 4  2011.0.00010.S  The Physics and Chemisty of Gas in Centaurus A...
#
#                                     project_abstract fs_type  low_freq  \
# 0  Centaurus A with its host NGC5128 is the most ...    line     90.38
# 1  Centaurus A with its host NGC5128 is the most ...    line     90.70
# 2  Centaurus A with its host NGC5128 is the most ...    line     91.69
# 3  Centaurus A with its host NGC5128 is the most ...    line     92.89
# 4  Centaurus A with its host NGC5128 is the most ...    line    217.59
#
#    high_freq  target  freq_diff  freq_med
# 0      90.62       1       0.24    90.500
# 1      90.93       1       0.23    90.815
# 2      91.92       1       0.23    91.805
# 3      93.12       1       0.23    93.005
# 4     218.53       1       0.94   218.060

# %%
import pandas as pd
import math

def adjust_frequency_ranges(df):
    new_rows = []
    
    # Group by project_code
    grouped = df.groupby('project_code')
    
    # Iterate through each group
    for _, group in grouped:
        # Sort by low_freq
        group = group.sort_values(by='low_freq')
        
        # Initialize variables for the new rows
        new_low = group.iloc[0]['low_freq']
        new_high = group.iloc[0]['high_freq']
        
        # Iterate through rows to find overlapping ranges
        for i in range(1, len(group)):
            if group.iloc[i]['low_freq'] <= new_high:
                # There's an overlap, adjust new_high
                new_high = max(new_high, group.iloc[i]['high_freq'])
            else:
                # No overlap, add the previous range as a new row
                if new_high - new_low <= 4:
                    new_rows.append({'project_code': group.iloc[i-1]['project_code'],
                                     'low_freq': new_low,
                                     'high_freq': new_high})
                else:
                    # Split the range into multiple rows
                    num_ranges = math.ceil((new_high - new_low) / 4)
                    freq_step = (new_high - new_low) / num_ranges
                    for j in range(num_ranges):
                        new_rows.append({'project_code': group.iloc[i-1]['project_code'],
                                         'low_freq': new_low + j * freq_step,
                                         'high_freq': min(new_low + (j+1) * freq_step, new_high)})
                new_low = group.iloc[i]['low_freq']
                new_high = group.iloc[i]['high_freq']
        
        # Add the last range as a new row
        if new_high - new_low <= 4:
            new_rows.append({'project_code': group.iloc[-1]['project_code'],
                             'low_freq': new_low,
                             'high_freq': new_high})
        else:
            # Split the range into multiple rows
            num_ranges = math.ceil((new_high - new_low) / 4)
            freq_step = (new_high - new_low) / num_ranges
            for j in range(num_ranges):
                new_rows.append({'project_code': group.iloc[-1]['project_code'],
                                 'low_freq': new_low + j * freq_step,
                                 'high_freq': min(new_low + (j+1) * freq_step, new_high)})
    
    # Create a DataFrame from the new rows and concatenate with the original DataFrame
    new_df = pd.DataFrame(new_rows)
    #df = pd.concat([df, new_df])
    merged_measurements = pd.merge(new_df, df.drop(columns=['low_freq', 'high_freq', 'freq_diff', 'freq_med', 'fs_type', 'target']), on='project_code', how='left')
    
    # Drop duplicates and return the result
    return merged_measurements.drop_duplicates()

# Example usage:
# measurements = pd.read_csv('nrao_measurements.csv')
# measurements = adjust_frequency_ranges(measurements)

# %%
measurements = adjust_frequency_ranges(measurements)

# %%
measurements['Band'] = np.where(measurements['high_freq'] < 43.5, 1, 
                                np.where(measurements['high_freq'] < 97.5, 2,
                                np.where(measurements['high_freq'] < 101.4, 3,
                                np.where(measurements['high_freq'] < 145.7, 4,
                                np.where(measurements['high_freq'] < 170.9, 5,
                                np.where(measurements['high_freq'] < 216.51, 6,
                                np.where(measurements['high_freq'] < 356.231, 7,
                                np.where(measurements['high_freq'] < 479.51, 8,
                                np.where(measurements['high_freq'] < 674.1, 9,
                                10)))))))))

# %%
measurements
# Out:
#           project_code    low_freq   high_freq  \
# 0       2011.0.00010.S   85.960000   86.190000
# 20      2011.0.00010.S   87.050000   87.290000
# 40      2011.0.00010.S   87.470000   87.880000
# 60      2011.0.00010.S   88.360000   88.590000
# 80      2011.0.00010.S   88.910000   89.150000
# ...                ...         ...         ...
# 396663  2023.A.00003.S  260.134444  263.823333
# 396683  2023.A.00003.S  263.823333  267.512222
# 396703  2023.A.00003.S  267.512222  271.201111
# 396723  2023.A.00003.S  271.201111  274.890000
# 396743  2023.A.00009.S  344.010000  347.790000
#
#                                             project_title  \
# 0       The Physics and Chemisty of Gas in Centaurus A...
# 20      The Physics and Chemisty of Gas in Centaurus A...
# 40      The Physics and Chemisty of Gas in Centaurus A...
# 60      The Physics and Chemisty of Gas in Centaurus A...
# 80      The Physics and Chemisty of Gas in Centaurus A...
# ...                                                   ...
# 396663  [OIII] Confirmation for Intrinsically Luminous...
# 396683  [OIII] Confirmation for Intrinsically Luminous...
# 396703  [OIII] Confirmation for Intrinsically Luminous...
# 396723  [OIII] Confirmation for Intrinsically Luminous...
# 396743  Finding t=0: Tracing the Origins of Rocky Plan...
#
#                                          project_abstract  Band
# 0       Centaurus A with its host NGC5128 is the most ...     2
# 20      Centaurus A with its host NGC5128 is the most ...     2
# 40      Centaurus A with its host NGC5128 is the most ...     2
# 60      Centaurus A with its host NGC5128 is the most ...     2
# 80      Centaurus A with its host NGC5128 is the most ...     2
# ...                                                   ...   ...
# 396663  Spectroscopic confirmation of the brightest, h...     7
# 396683  Spectroscopic confirmation of the brightest, h...     7
# 396703  Spectroscopic confirmation of the brightest, h...     7
# 396723  Spectroscopic confirmation of the brightest, h...     7
# 396743  Recent JWST observations serendipitously revea...     7
#
# [18717 rows x 6 columns]

# %%
#convert to lowercase, strip and remove punctuations and remove ALMA, case insensitive
def preprocess(text):
    text = text.lower()
    text = text.strip()
    text = re.compile('<.*?>').sub('', text) 
    text = re.compile('[%s]' % re.escape(string.punctuation)).sub(' ', text)  
    text = re.sub(r'(?i)alma', '', text)
    text = re.sub('\s+', ' ', text)  
    text = re.sub(r'\[[0-9]*\]',' ',text) 
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
    text = re.sub(r'\d',' ',text) 
    text = re.sub(r'\s+',' ',text) 
    return text
 
# STOPWORD REMOVAL
def stopword(string):
    a= [i for i in string.split() if i not in stopwords.words('english')]
    return ' '.join(a)

#LEMMATIZATION
# Initialize the lemmatizer
wl = WordNetLemmatizer()
 
# This is a helper function to map NTLK position tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def lemmatizer(string):
    word_pos_tags = nltk.pos_tag(word_tokenize(string)) # Get position tags
    a=[wl.lemmatize(tag[0], get_wordnet_pos(tag[1])) for idx, tag in enumerate(word_pos_tags)] # Map the position tag and lemmatize the word/token
    return " ".join(a)

# %%
measurements['raw_text'] = str(measurements.project_title.str.strip() + '. ' + measurements.project_abstract.str.strip())
#print(type(measurements['raw_text']))
measurements['standardized_text'] = measurements.raw_text.apply(lambda x: preprocess(x))
measurements['no_sw_text'] = measurements.standardized_text.apply(lambda x: stopword(x))
measurements['lemmatized_sw_text'] = measurements.standardized_text.apply(lambda x: lemmatizer(x))
measurements['lemmatized_no_sw_text'] = measurements.no_sw_text.apply(lambda x: lemmatizer(x))
measurements
# Out:
#           project_code    low_freq   high_freq  \
# 0       2011.0.00010.S   85.960000   86.190000
# 20      2011.0.00010.S   87.050000   87.290000
# 40      2011.0.00010.S   87.470000   87.880000
# 60      2011.0.00010.S   88.360000   88.590000
# 80      2011.0.00010.S   88.910000   89.150000
# ...                ...         ...         ...
# 396663  2023.A.00003.S  260.134444  263.823333
# 396683  2023.A.00003.S  263.823333  267.512222
# 396703  2023.A.00003.S  267.512222  271.201111
# 396723  2023.A.00003.S  271.201111  274.890000
# 396743  2023.A.00009.S  344.010000  347.790000
#
#                                             project_title  \
# 0       The Physics and Chemisty of Gas in Centaurus A...
# 20      The Physics and Chemisty of Gas in Centaurus A...
# 40      The Physics and Chemisty of Gas in Centaurus A...
# 60      The Physics and Chemisty of Gas in Centaurus A...
# 80      The Physics and Chemisty of Gas in Centaurus A...
# ...                                                   ...
# 396663  [OIII] Confirmation for Intrinsically Luminous...
# 396683  [OIII] Confirmation for Intrinsically Luminous...
# 396703  [OIII] Confirmation for Intrinsically Luminous...
# 396723  [OIII] Confirmation for Intrinsically Luminous...
# 396743  Finding t=0: Tracing the Origins of Rocky Plan...
#
#                                          project_abstract  Band  \
# 0       Centaurus A with its host NGC5128 is the most ...     2
# 20      Centaurus A with its host NGC5128 is the most ...     2
# 40      Centaurus A with its host NGC5128 is the most ...     2
# 60      Centaurus A with its host NGC5128 is the most ...     2
# 80      Centaurus A with its host NGC5128 is the most ...     2
# ...                                                   ...   ...
# 396663  Spectroscopic confirmation of the brightest, h...     7
# 396683  Spectroscopic confirmation of the brightest, h...     7
# 396703  Spectroscopic confirmation of the brightest, h...     7
# 396723  Spectroscopic confirmation of the brightest, h...     7
# 396743  Recent JWST observations serendipitously revea...     7
#
#                                                  raw_text  \
# 0       0         The Physics and Chemisty of Gas in C...
# 20      0         The Physics and Chemisty of Gas in C...
# 40      0         The Physics and Chemisty of Gas in C...
# 60      0         The Physics and Chemisty of Gas in C...
# 80      0         The Physics and Chemisty of Gas in C...
# ...                                                   ...
# 396663  0         The Physics and Chemisty of Gas in C...
# 396683  0         The Physics and Chemisty of Gas in C...
# 396703  0         The Physics and Chemisty of Gas in C...
# 396723  0         The Physics and Chemisty of Gas in C...
# 396743  0         The Physics and Chemisty of Gas in C...
#
#                                         standardized_text  \
# 0        the physics and chemisty of gas in centaurus ...
# 20       the physics and chemisty of gas in centaurus ...
# 40       the physics and chemisty of gas in centaurus ...
# 60       the physics and chemisty of gas in centaurus ...
# 80       the physics and chemisty of gas in centaurus ...
# ...                                                   ...
# 396663   the physics and chemisty of gas in centaurus ...
# 396683   the physics and chemisty of gas in centaurus ...
# 396703   the physics and chemisty of gas in centaurus ...
# 396723   the physics and chemisty of gas in centaurus ...
# 396743   the physics and chemisty of gas in centaurus ...
#
#                                                no_sw_text  \
# 0       physics chemisty gas centaurus physics chemist...
# 20      physics chemisty gas centaurus physics chemist...
# 40      physics chemisty gas centaurus physics chemist...
# 60      physics chemisty gas centaurus physics chemist...
# 80      physics chemisty gas centaurus physics chemist...
# ...                                                   ...
# 396663  physics chemisty gas centaurus physics chemist...
# 396683  physics chemisty gas centaurus physics chemist...
# 396703  physics chemisty gas centaurus physics chemist...
# 396723  physics chemisty gas centaurus physics chemist...
# 396743  physics chemisty gas centaurus physics chemist...
#
#                                        lemmatized_sw_text  \
# 0       the physic and chemisty of gas in centaurus a ...
# 20      the physic and chemisty of gas in centaurus a ...
# 40      the physic and chemisty of gas in centaurus a ...
# 60      the physic and chemisty of gas in centaurus a ...
# 80      the physic and chemisty of gas in centaurus a ...
# ...                                                   ...
# 396663  the physic and chemisty of gas in centaurus a ...
# 396683  the physic and chemisty of gas in centaurus a ...
# 396703  the physic and chemisty of gas in centaurus a ...
# 396723  the physic and chemisty of gas in centaurus a ...
# 396743  the physic and chemisty of gas in centaurus a ...
#
#                                     lemmatized_no_sw_text
# 0       physic chemisty gas centaurus physic chemisty ...
# 20      physic chemisty gas centaurus physic chemisty ...
# 40      physic chemisty gas centaurus physic chemisty ...
# 60      physic chemisty gas centaurus physic chemisty ...
# 80      physic chemisty gas centaurus physic chemisty ...
# ...                                                   ...
# 396663  physic chemisty gas centaurus physic chemisty ...
# 396683  physic chemisty gas centaurus physic chemisty ...
# 396703  physic chemisty gas centaurus physic chemisty ...
# 396723  physic chemisty gas centaurus physic chemisty ...
# 396743  physic chemisty gas centaurus physic chemisty ...
#
# [18717 rows x 11 columns]

# %%
final_measurements = measurements[['lemmatized_no_sw_text']]

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_projects = tfidf_vectorizer.fit_transform(final_measurements.lemmatized_no_sw_text)
tfidf_vectorizer.get_feature_names_out()
# Out:
# array(['centaurus', 'chemisty', 'confirmation', 'dtype', 'find', 'gas',
#        'intrinsically', 'length', 'luminous', 'object', 'oiii', 'origin',
#        'physic', 'plan', 'rocky', 'trace'], dtype=object)

# %%
import random

def split_list_into_random_groups(data, num_groups):
    # Shuffle the data randomly
    random.shuffle(data)
    
    # Calculate the size of each group
    group_size = len(data) // num_groups
    remainder = len(data) % num_groups

    groups = []
    start = 0
    for i in range(num_groups):
        if i < remainder:
            end = start + group_size + 1
        else:
            end = start + group_size
        groups.append(data[start:end])
        start = end

    return groups

# Example usage:
data = np.arange(18717)
num_groups = 5
groups = split_list_into_random_groups(data, num_groups)
for i, group in enumerate(groups):
    print(f"Group {i+1}: {group}")
# Out:
# Group 1: [ 8266 14159  7148 ...  2190 16481   360]
# Group 2: [18022  4098 12538 ... 13222  3383  1810]
# Group 3: [ 1256 15754 12933 ... 12811    13  6859]
# Group 4: [15759  1985 11562 ...  9218  7166  8251]
# Group 5: [16323  6664 10920 ... 14045 11170 10665]

# %%
train_band = np.concatenate((groups[0], groups[1]))
train_med = groups[2]
train_width = groups[3]
test = groups[4]

# %%
count_vectorizer = CountVectorizer()
cv_projects = count_vectorizer.fit_transform(final_measurements.lemmatized_no_sw_text)
#count_vectorizer.get_feature_names_out()
text_band = cv_projects[train_band]
text_test = cv_projects[test]

# %%
band_labels = measurements['Band'].reset_index(drop=True)
labels_train_band = band_labels.filter(items=train_band, axis=0)
labels_test_band = band_labels.filter(items=test, axis=0)
dict_train_band = labels_train_band.value_counts().to_dict()

# %%
dict_train_band
# Out:
# {7: 4239,
#  4: 1010,
#  2: 709,
#  8: 339,
#  6: 328,
#  5: 277,
#  3: 275,
#  9: 170,
#  10: 138,
#  1: 3}

# %%
n_samples = len(measurements)
n_classes = 10
n_ind = [1, dict_train_band[2], dict_train_band[3], 
         dict_train_band[4], dict_train_band[5], dict_train_band[6], 
         dict_train_band[7], dict_train_band[8], dict_train_band[9], 
         dict_train_band[10]]

# %%
weights = [1/(n_classes * x) for x in n_ind]
weights = [x/sum(weights) for x in weights]
weights = [0, .1, .2, .1, .1, .1, 0, .1, .2, .1]

# %%
class_weight.compute_sample_weight('balanced', labels_train_band)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 class_weight.compute_sample_weight('balanced', labels_train_band)
#
# NameError: name 'class_weight' is not defined

# %%
text_band
# Out:
# <1x16 sparse matrix of type '<class 'numpy.int64'>'
# 	with 16 stored elements in Compressed Sparse Row format>

# %%
clf = sklearn.naive_bayes.MultinomialNB(class_prior = weights)
clf.fit(text_band, labels_train_band)

# %%
#always predicting the same class for all?
clf.predict(text_test)

# %% [markdown]
# ##
